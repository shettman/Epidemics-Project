# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states
import gmaps

# Census & gmaps API Keys
from config import (api_key, gkey)
c = Census(api_key, year= 2013)

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E", "B19301_001E", "B17001_002E", "B23025_005E", "B15003_002E", "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E", "B15003_024E", "B15003_025E", "B02001_002E", "B02001_003E", "B02001_004E", "B02001_005E", "B02001_006E", "B02001_008E", "B03001_003E"), {'for': 'state:*'})
#"B15003_002E"

# Make dataframe
census_pd = pd.DataFrame(census_data)
census_pd.head()
# Out:
#    B01002_001E  B01003_001E  B02001_002E  B02001_003E  B02001_004E  \
# 0         38.1    4799277.0    3326188.0    1262152.0      25278.0
# 1         33.6     720316.0     481638.0      25033.0     101273.0
# 2         36.3    6479703.0    5131739.0     270027.0     286953.0
# 3         37.5    2933369.0    2295446.0     454903.0      17945.0
# 4         35.4   37659181.0   23467167.0    2255372.0     286397.0
#
#    B02001_005E  B02001_006E  B02001_008E  B03001_003E  B15003_002E  ...  \
# 0      56831.0       1387.0      72145.0     188294.0      40711.0  ...
# 1      39200.0       8013.0      56757.0      42832.0       2796.0  ...
# 2     182953.0      12607.0     191265.0    1935948.0      52419.0  ...
# 3      37776.0       5697.0      58307.0     192264.0      22954.0  ...
# 4    5005635.0     146290.0    1627359.0   14270345.0     598141.0  ...
#
#    B15003_022E  B15003_023E  B15003_024E  B15003_025E  B17001_002E  \
# ...

# %%
# Reorder columns 
census_pd = census_pd.rename(columns={"B01003_001E": "Total Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Median Household Income Per Year (Dollars)",
                                      "B19301_001E": "Income Per Capita Per Year (Dollars)",
                                      "B17001_002E": "Number of People Living in Poverty",
                                      "B23025_005E": "Unemployment Count (16+)",
                                      "B15003_002E": "Number of People Who Completed No Schooling (25+)",
                                      "B15003_017E": "Number of People with High School Degree (25+)",
                                      "B15003_018E": "Number of People with GED (25+)",
                                      "B15003_021E": "Number of People with Associates Degree (25+)",
                                      "B15003_022E": "Number of People with Bachelors Degree (25+)",
                                      "B15003_023E": "Number of People with Masters Degree (25+)",
                                      "B15003_024E": "Number of People with Professional Degree (25+)",
                                      "B15003_025E": "Number of People with Doctoral Degree (25+)",
                                      "B02001_002E": "Number of People of European American Origin",
                                      "B02001_003E": "Number of People of African American Origin",
                                      "B02001_004E": "Number of People of Native American Origin",
                                      "B02001_005E": "Number of People of Asian Origin",
                                      "B02001_006E": "Number of People of Pacific Islander Origin",
                                      "B03001_003E": "Number of People of Hispanic Origin",
                                      "B02001_008E": "Number of People of Multiethnic Origin",
                                      "NAME": "Name", "state": "State"  
})

census_pd.head()
# Out:
#    Median Age  Total Population  Number of People of European American Origin  \
# 0        38.1         4799277.0                                     3326188.0
# 1        33.6          720316.0                                      481638.0
# 2        36.3         6479703.0                                     5131739.0
# 3        37.5         2933369.0                                     2295446.0
# 4        35.4        37659181.0                                    23467167.0
#
#    Number of People of African American Origin  \
# 0                                    1262152.0
# 1                                      25033.0
# 2                                     270027.0
# 3                                     454903.0
# 4                                    2255372.0
#
#    Number of People of Native American Origin  \
# 0                                     25278.0
# 1                                    101273.0
# 2                                    286953.0
# ...

# %%
# Add in Percentage of People Living in Poverty (Number of People Living in Poverty / Total Population)
census_pd["Percentage of People Living in Poverty"] = (census_pd["Number of People Living in Poverty"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Employment Rate (Employment Count / Population)
census_pd["Percentage of Unemployed"] = (census_pd["Unemployment Count (16+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed No Schooling (25+) Rate (No school / Population)
census_pd["Percentage of People Who Completed No Schooling (25+)"] = (census_pd["Number of People Who Completed No Schooling (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed High School Rate (High school / Population)
census_pd["Percentage of People with High School Degree (25+)"] = (census_pd["Number of People with High School Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed GED Rate (GED/ Population)
census_pd["Percentage of People with GED (25+)"] = (census_pd["Number of People with GED (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed Associates Rate (Associates/ Population)
census_pd["Percentage of People with Associates Degree (25+)"] = (census_pd["Number of People with Associates Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed Bachelors Rate (Bachelors/ Population)
census_pd["Percentage of People with Bachelors Degree (25+)"] = (census_pd["Number of People with Bachelors Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed Masters Rate (Masters/ Population)
census_pd["Percentage of People with Masters Degree (25+)"] = (census_pd["Number of People with Masters Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed Professional Rate (Professional/ Population)
census_pd["Percentage of People with Professional Degree (25+)"] = (census_pd["Number of People with Professional Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People Who Completed Doctoral Rate (Doctoral/ Population)
census_pd["Percentage of People with Doctoral Degree (25+)"] = (census_pd["Number of People with Doctoral Degree (25+)"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of European American Origin (European American Origin/ Population)
census_pd["Percentage of People of European American Origin"] = (census_pd["Number of People of European American Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of African American Origin (Number of People of African American Origin/ Population)
census_pd["Percentage of People of African American Origin"] = (census_pd["Number of People of African American Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of Native American Origin (Number of People of Native American Origin/ Population)
census_pd["Percentage of People of Native American Origin"] = (census_pd["Number of People of Native American Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of Asian American Origin (Number of People of Asian American Origin/ Population)
census_pd["Percentage of People of Asian Origin"] = (census_pd["Number of People of Asian Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of Pacific Islander Origin (Number of People of Pacific Islander Origin/ Population)
census_pd["Percentage of People of Pacific Islander Origin"] = (census_pd["Number of People of Pacific Islander Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of Hispanic Origin (Number of People of Hispanic Origin/ Population)
census_pd["Percentage of People of Hispanic Origin"] = (census_pd["Number of People of Hispanic Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Add in Percentage of People of Multiethnic Origin (Number of People of Hispanic Origin/ Population)
census_pd["Percentage of People of Multiethnic Origin"] = (census_pd["Number of People of Multiethnic Origin"].astype(int) / census_pd["Total Population"].astype(int)) * 100

# %%
# Final DataFrame
census_pd_edit = census_pd[["State", "Name", "Total Population", "Median Age", "Median Household Income Per Year (Dollars)", "Income Per Capita Per Year (Dollars)", "Percentage of People Living in Poverty", "Percentage of Unemployed", "Percentage of People Who Completed No Schooling (25+)", "Percentage of People with High School Degree (25+)", "Percentage of People with GED (25+)", "Percentage of People with Associates Degree (25+)", "Percentage of People with Bachelors Degree (25+)", "Percentage of People with Masters Degree (25+)", "Percentage of People with Professional Degree (25+)", "Percentage of People with Doctoral Degree (25+)", "Percentage of People of European American Origin", "Percentage of People of African American Origin", "Percentage of People of Native American Origin", "Percentage of People of Asian Origin", "Percentage of People of Pacific Islander Origin", "Percentage of People of Hispanic Origin", "Percentage of People of Multiethnic Origin"]]

census_pd_edit.head()
# Out:
#   State        Name  Total Population  Median Age  \
# 0    01     Alabama         4799277.0        38.1
# 1    02      Alaska          720316.0        33.6
# 2    04     Arizona         6479703.0        36.3
# 3    05    Arkansas         2933369.0        37.5
# 4    06  California        37659181.0        35.4
#
#    Median Household Income Per Year (Dollars)  \
# 0                                     43253.0
# 1                                     70760.0
# 2                                     49774.0
# 3                                     40768.0
# 4                                     61094.0
#
#    Income Per Capita Per Year (Dollars)  \
# 0                               23680.0
# 1                               32651.0
# 2                               25358.0
# 3                               22170.0
# 4                               29527.0
#
#    Percentage of People Living in Poverty  Percentage of Unemployed  \
# ...

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd_edit.to_csv("census_data_states_summary_2013_2018.csv", encoding="utf-8", index=False)
