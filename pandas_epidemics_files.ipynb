# %%
# Dependencies
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

# %%
# Store filepath in a variable
file_one = "Resources/hepatitis.csv"
file_two = "Resources/measles.csv"
file_three = "Resources/mumps.csv"
file_four = "Resources/pertussis.csv"
file_five = "Resources/polio.csv"
file_six = "Resources/rubella.csv"
file_seven = "Resources/smallpox.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")
file_three_df = pd.read_csv(file_three, encoding="ISO-8859-1")
file_four_df = pd.read_csv(file_four, encoding="ISO-8859-1")
file_five_df = pd.read_csv(file_five, encoding="ISO-8859-1")
file_six_df = pd.read_csv(file_six, encoding="ISO-8859-1")
file_seven_df = pd.read_csv(file_seven, encoding="ISO-8859-1")

# %%
file_five_df.dropna(subset=["cases"], axis = 0 , inplace= True)
file_five_df.head()
# Out:
#      week state  state_name disease cases  incidence_per_capita
# 0  192801    AL     ALABAMA   POLIO     0                  0.00
# 1  192801    AR    ARKANSAS   POLIO     0                  0.00
# 2  192801    AZ     ARIZONA   POLIO     0                  0.00
# 3  192801    CA  CALIFORNIA   POLIO     9                  0.17
# 4  192801    CO    COLORADO   POLIO     4                  0.39

# %%
# Show just the header
file_one_df.head()
# Out:
#      week state  state_name      disease  cases  incidence_per_capita
# 0  196601    AL     ALABAMA  HEPATITIS A      5                  0.14
# 1  196601    AR    ARKANSAS  HEPATITIS A     11                  0.58
# 2  196601    AZ     ARIZONA  HEPATITIS A      6                  0.37
# 3  196601    CA  CALIFORNIA  HEPATITIS A     89                  0.47
# 4  196601    CO    COLORADO  HEPATITIS A      1                  0.05

# %%
renamefile_one_df = file_one_df.rename(columns={"incidence_per_capita": "Hepatitis A incidence_per_capita", "cases": "Hepatitis A cases"})
renamefile_two_df = file_two_df.rename(columns={"incidence_per_capita": "measles incidence_per_capita", "cases": "measles cases"})
renamefile_three_df = file_three_df.rename(columns={"incidence_per_capita": "mumps incidence_per_capita", "cases": "mumps cases" })
renamefile_four_df = file_four_df.rename(columns={"incidence_per_capita": "pertussis incidence_per_capita", "cases": "pertussis cases"})
renamefile_five_df = file_five_df.rename(columns={"incidence_per_capita": "polio incidence_per_capita", "cases": "polio cases"})
renamefile_six_df = file_six_df.rename(columns={"incidence_per_capita": "rubella incidence_per_capita", "cases": "rubella cases"})
renamefile_seven_df = file_seven_df.rename(columns={"incidence_per_capita": "smallpox incidence_per_capita", "cases": "smallpox cases"})

renamefile_five_df.head()
# Out:
#      week state  state_name disease polio cases  polio incidence_per_capita
# 0  192801    AL     ALABAMA   POLIO           0                        0.00
# 1  192801    AR    ARKANSAS   POLIO           0                        0.00
# 2  192801    AZ     ARIZONA   POLIO           0                        0.00
# 3  192801    CA  CALIFORNIA   POLIO           9                        0.17
# 4  192801    CO    COLORADO   POLIO           4                        0.39

# %%
#Drop state column
df1 = renamefile_one_df.drop(columns=["state"])
df2 = renamefile_two_df .drop(columns=["state"])
df3 = renamefile_three_df .drop(columns=["state"])
df4 = renamefile_four_df .drop(columns=["state"])
df5 = renamefile_five_df .drop(columns=["state"])
df6 = renamefile_six_df .drop(columns=["state"])
df7 = renamefile_seven_df .drop(columns=["state"])
df1.head()
# Out:
#      week  state_name      disease  Hepatitis A cases  \
# 0  196601     ALABAMA  HEPATITIS A                  5
# 1  196601    ARKANSAS  HEPATITIS A                 11
# 2  196601     ARIZONA  HEPATITIS A                  6
# 3  196601  CALIFORNIA  HEPATITIS A                 89
# 4  196601    COLORADO  HEPATITIS A                  1
#
#    Hepatitis A incidence_per_capita
# 0                              0.14
# 1                              0.58
# 2                              0.37
# 3                              0.47
# 4                              0.05

# %%
# Drop state_name column
df_1 = df1
df_2 = df2.drop(columns=["state_name"])
df_3 = df3.drop(columns=["state_name"])
df_4 = df4.drop(columns=["state_name"])
df_5 = df5.drop(columns=["state_name"])
df_6 = df6.drop(columns=["state_name"])
df_7 = df7.drop(columns=["state_name"])
df_7.head()
# Out:
#      week   disease  smallpox cases  smallpox incidence_per_capita
# 0  192801  SMALLPOX               1                           0.04
# 1  192801  SMALLPOX               7                           0.38
# 2  192801  SMALLPOX               0                           0.00
# 3  192801  SMALLPOX              18                           0.34
# 4  192801  SMALLPOX              31                           3.06

# %%
# Concat
df_8 = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7], axis=1, join='inner').sort_index()

# Drop week column
df_9 = df_8.drop(columns=["week"])
df_9
# Out:
#                  state_name      disease  Hepatitis A cases  \
# 0                   ALABAMA  HEPATITIS A                  5
# 1                  ARKANSAS  HEPATITIS A                 11
# 2                   ARIZONA  HEPATITIS A                  6
# 3                CALIFORNIA  HEPATITIS A                 89
# 4                  COLORADO  HEPATITIS A                  1
# 5               CONNECTICUT  HEPATITIS A                  9
# 6                  DELAWARE  HEPATITIS A                  3
# 7                   FLORIDA  HEPATITIS A                  7
# 8                   GEORGIA  HEPATITIS A                  4
# 9                    HAWAII  HEPATITIS A                  3
# 10                     IOWA  HEPATITIS A                 12
# 11                    IDAHO  HEPATITIS A                  2
# 12                 ILLINOIS  HEPATITIS A                  6
# 13                  INDIANA  HEPATITIS A                  2
# 14                   KANSAS  HEPATITIS A                  6
# 15                 KENTUCKY  HEPATITIS A                 26
# 16                LOUISIANA  HEPATITIS A                  1
# 17            MASSACHUSETTS  HEPATITIS A                 10
# 18                 MARYLAND  HEPATITIS A                  9
# 19                    MAINE  HEPATITIS A                  6
# 20                 MICHIGAN  HEPATITIS A                 84
# 21                MINNESOTA  HEPATITIS A                  3
# 22                 MISSOURI  HEPATITIS A                  5
# 23              MISSISSIPPI  HEPATITIS A                  1
# 24                  MONTANA  HEPATITIS A                  2
# 25           NORTH CAROLINA  HEPATITIS A                  8
# 26             NORTH DAKOTA  HEPATITIS A                  1
# 27            NEW HAMPSHIRE  HEPATITIS A                  3
# 28               NEW JERSEY  HEPATITIS A                 21
# 29               NEW MEXICO  HEPATITIS A                 13
# ...                     ...          ...                ...
# 50886            NEW MEXICO  HEPATITIS A                  9
# 50887                NEVADA  HEPATITIS A                  8
# 50888              NEW YORK  HEPATITIS A                  9
# 50889                  OHIO  HEPATITIS A                  5
# 50890              OKLAHOMA  HEPATITIS A                  7
# 50891                OREGON  HEPATITIS A                  6
# 50892          PENNSYLVANIA  HEPATITIS A                  7
# 50893          RHODE ISLAND  HEPATITIS A                  2
# 50894        SOUTH CAROLINA  HEPATITIS A                  1
# 50895          SOUTH DAKOTA  HEPATITIS A                 13
# 50896             TENNESSEE  HEPATITIS A                  4
# 50897                 TEXAS  HEPATITIS A                 75
# 50898                  UTAH  HEPATITIS A                  3
# 50899              VIRGINIA  HEPATITIS A                  4
# 50900               VERMONT  HEPATITIS A                  0
# 50901            WASHINGTON  HEPATITIS A                 13
# 50902             WISCONSIN  HEPATITIS A                  8
# 50903         WEST VIRGINIA  HEPATITIS A                  0
# 50904               WYOMING  HEPATITIS A                  0
# 50905                ALASKA  HEPATITIS A                  0
# 50906               ALABAMA  HEPATITIS A                  2
# 50907              ARKANSAS  HEPATITIS A                  7
# 50908               ARIZONA  HEPATITIS A                 35
# 50909            CALIFORNIA  HEPATITIS A                 76
# 50910              COLORADO  HEPATITIS A                 16
# 50911           CONNECTICUT  HEPATITIS A                  0
# 50912  DISTRICT OF COLUMBIA  HEPATITIS A                  1
# 50913              DELAWARE  HEPATITIS A                  0
# 50914               FLORIDA  HEPATITIS A                 13
# 50915               GEORGIA  HEPATITIS A                  1
#
#        Hepatitis A incidence_per_capita  disease  measles cases  \
# 0                                  0.14  MEASLES             97
# 1                                  0.58  MEASLES             76
# 2                                  0.37  MEASLES              8
# 3                                  0.47  MEASLES             74
# 4                                  0.05  MEASLES             85
# 5                                  0.31  MEASLES             71
# 6                                  0.58  MEASLES             20
# 7                                  0.11  MEASLES              3
# 8                                  0.09  MEASLES             34
# 9                                  0.42  MEASLES              4
# 10                                 0.43  MEASLES             38
# 11                                 0.29  MEASLES             43
# 12                                 0.06  MEASLES             15
# 13                                 0.04  MEASLES             79
# 14                                 0.27  MEASLES             39
# 15                                 0.83  MEASLES           1082
# 16                                 0.03  MEASLES            175
# 17                                 0.18  MEASLES             36
# 18                                 0.24  MEASLES            265
# 19                                 0.60  MEASLES              8
# 20                                 0.99  MEASLES             43
# 21                                 0.08  MEASLES              1
# 22                                 0.11  MEASLES           1475
# 23                                 0.04  MEASLES             22
# 24                                 0.28  MEASLES            141
# 25                                 0.16  MEASLES             62
# 26                                 0.15  MEASLES            882
# 27                                 0.44  MEASLES            166
# 28                                 0.31  MEASLES            114
# 29                                 1.29  MEASLES             46
# ...                                 ...      ...            ...
# 50886                              0.58  MEASLES              1
# 50887                              0.62  MEASLES              7
# 50888                              0.05  MEASLES             30
# 50889                              0.05  MEASLES            376
# 50890                              0.22  MEASLES             49
# 50891                              0.20  MEASLES             16
# 50892                              0.06  MEASLES             18
# 50893                              0.20  MEASLES              3
# 50894                              0.03  MEASLES            363
# 50895                              1.85  MEASLES             23
# 50896                              0.08  MEASLES              3
# 50897                              0.43  MEASLES            178
# 50898                              0.17  MEASLES             61
# 50899                              0.06  MEASLES             33
# 50900                              0.00  MEASLES             15
# 50901                              0.26  MEASLES              4
# 50902                              0.16  MEASLES             11
# 50903                              0.00  MEASLES             23
# 50904                              0.00  MEASLES              3
# 50905                              0.00  MEASLES            741
# 50906                              0.05  MEASLES              8
# 50907                              0.29  MEASLES            826
# 50908                              0.92  MEASLES            346
# 50909                              0.25  MEASLES              8
# 50910                              0.47  MEASLES              4
# 50911                              0.00  MEASLES            392
# 50912                              0.17  MEASLES              2
# 50913                              0.00  MEASLES              4
# 50914                              0.10  MEASLES              5
# 50915                              0.02  MEASLES             10
#
#        measles incidence_per_capita  disease  mumps cases  \
# 0                              3.67    MUMPS            7
# 1                              4.11    MUMPS           39
# 2                              1.90    MUMPS           19
# 3                              1.38    MUMPS          247
# 4                              8.38    MUMPS            1
# 5                              4.50    MUMPS            9
# 6                              8.58    MUMPS           36
# 7                              0.21    MUMPS           13
# 8                              1.17    MUMPS          351
# 9                              0.16    MUMPS            3
# 10                             0.50    MUMPS           72
# 11                             1.34    MUMPS           57
# 12                             0.81    MUMPS          107
# 13                             3.08    MUMPS          212
# 14                             1.89    MUMPS            8
# 15                            25.66    MUMPS           25
# 16                            10.87    MUMPS          176
# 17                             4.52    MUMPS            2
# 18                             5.68    MUMPS           12
# 19                             0.31    MUMPS           10
# 20                             1.19    MUMPS            3
# 21                             0.18    MUMPS           37
# 22                            47.86    MUMPS           15
# 23                             1.60    MUMPS          195
# 24                             3.55    MUMPS            5
# 25                            14.90    MUMPS          152
# 26                             7.60    MUMPS            1
# 27                             2.51    MUMPS           15
# 28                             4.86    MUMPS           80
# 29                             4.91    MUMPS            4
# ...                             ...      ...          ...
# 50886                          0.20    MUMPS            0
# 50887                          0.27    MUMPS            0
# 50888                          5.08    MUMPS            2
# 50889                          4.30    MUMPS            0
# 50890                          1.24    MUMPS            2
# 50891                          0.84    MUMPS            0
# 50892                          0.61    MUMPS            0
# 50893                          0.11    MUMPS            0
# 50894                          7.75    MUMPS            1
# 50895                          0.98    MUMPS            0
# 50896                          0.33    MUMPS            0
# 50897                          2.78    MUMPS            0
# 50898                          2.04    MUMPS            1
# 50899                          0.83    MUMPS            3
# 50900                          0.69    MUMPS            5
# 50901                          0.67    MUMPS            1
# 50902                          0.27    MUMPS            0
# 50903                          3.72    MUMPS            0
# 50904                          0.56    MUMPS            0
# 50905                         15.21    MUMPS            0
# 50906                          1.16    MUMPS            3
# 50907                          5.56    MUMPS            5
# 50908                          4.34    MUMPS            1
# 50909                          0.36    MUMPS            1
# 50910                          0.26    MUMPS            1
# 50911                          3.73    MUMPS            0
# 50912                          0.25    MUMPS            4
# 50913                          0.19    MUMPS            0
# 50914                          0.76    MUMPS           10
# 50915                          0.30    MUMPS            3
#
#        mumps incidence_per_capita  ... pertussis incidence_per_capita  \
# 0                            2.46  ...                           0.79
# 1                            1.13  ...                           1.14
# 2                            1.13  ...                           4.08
# 3                            1.27  ...                           5.86
# 4                            0.13  ...                           0.90
# 5                            1.69  ...                           2.91
# 6                            0.56  ...                           2.66
# 7                            1.77  ...                           3.11
# 8                           12.52  ...                           0.11
# 9                            0.43  ...                           0.29
# 10                           0.65  ...                           1.28
# 11                           1.12  ...                           6.24
# 12                           3.35  ...                           1.32
# 13                           3.77  ...                           0.68
# 14                           0.21  ...                           5.65
# 15                           2.52  ...                           3.21
# 16                           2.02  ...                           4.12
# 17                           0.05  ...                           3.11
# 18                           0.26  ...                          15.54
# 19                           0.45  ...                           1.96
# 20                           0.43  ...                           2.40
# 21                           5.96  ...                           1.27
# 22                           1.02  ...                          12.14
# 23                           2.78  ...                           9.53
# 24                           0.50  ...                           3.86
# 25                           1.45  ...                           1.21
# 26                           0.04  ...                           1.24
# 27                           0.75  ...                           5.24
# 28                           8.68  ...                           3.70
# 29                           0.16  ...                           2.58
# ...                           ...  ...                            ...
# 50886                        0.00  ...                           0.02
# 50887                        0.00  ...                           0.02
# 50888                        0.01  ...                           0.10
# 50889                        0.00  ...                           0.04
# 50890                        0.03  ...                           0.00
# 50891                        0.00  ...                           0.00
# 50892                        0.00  ...                           0.18
# 50893                        0.00  ...                           0.00
# 50894                        0.06  ...                           0.00
# 50895                        0.00  ...                           0.00
# 50896                        0.00  ...                           0.02
# 50897                        0.00  ...                           0.00
# 50898                        0.04  ...                           0.00
# 50899                        0.08  ...                           0.00
# 50900                        0.02  ...                           0.00
# 50901                        0.03  ...                           0.00
# 50902                        0.00  ...                           0.00
# 50903                        0.00  ...                           0.00
# 50904                        0.00  ...                           0.02
# 50905                        0.00  ...                           0.00
# 50906                        0.05  ...                           0.50
# 50907                        0.45  ...                           0.00
# 50908                        0.04  ...                           0.00
# 50909                        0.10  ...                           0.00
# 50910                        0.01  ...                           0.02
# 50911                        0.00  ...                           0.00
# 50912                        0.09  ...                           0.06
# 50913                        0.00  ...                           0.00
# 50914                        0.21  ...                           0.00
# 50915                        0.03  ...                           0.00
#
#        disease  polio cases polio incidence_per_capita  disease  \
# 0        POLIO            0                       0.00  RUBELLA
# 1        POLIO            0                       0.00  RUBELLA
# 2        POLIO            0                       0.00  RUBELLA
# 3        POLIO            9                       0.17  RUBELLA
# 4        POLIO            4                       0.39  RUBELLA
# 5        POLIO            0                       0.00  RUBELLA
# 6        POLIO            0                       0.00  RUBELLA
# 7        POLIO            0                       0.00  RUBELLA
# 8        POLIO            1                       0.03  RUBELLA
# 9        POLIO            2                       0.08  RUBELLA
# 10       POLIO            0                       0.00  RUBELLA
# 11       POLIO            2                       0.03  RUBELLA
# 12       POLIO            1                       0.03  RUBELLA
# 13       POLIO            0                       0.00  RUBELLA
# 14       POLIO            0                       0.00  RUBELLA
# 15       POLIO            0                       0.00  RUBELLA
# 16       POLIO            6                       0.14  RUBELLA
# 17       POLIO            1                       0.06  RUBELLA
# 18       POLIO            0                       0.00  RUBELLA
# 19       POLIO            2                       0.04  RUBELLA
# 20       POLIO            0                       0.00  RUBELLA
# 21       POLIO            1                       0.03  RUBELLA
# 22       POLIO            0                       0.00  RUBELLA
# 23       POLIO            1                       0.18  RUBELLA
# 24       POLIO            0                       0.00  RUBELLA
# 25       POLIO            1                       0.07  RUBELLA
# 26       POLIO            3                       0.08  RUBELLA
# 27       POLIO            0                       0.00  RUBELLA
# 28       POLIO            9                       0.08  RUBELLA
# 29       POLIO            1                       0.02  RUBELLA
# ...        ...          ...                        ...      ...
# 50886    POLIO            1                       0.05  RUBELLA
# 50887    POLIO            5                       0.07  RUBELLA
# 50888    POLIO            1                       0.15  RUBELLA
# 50889    POLIO            3                       0.13  RUBELLA
# 50890    POLIO            1                       0.03  RUBELLA
# 50891    POLIO            6                       0.31  RUBELLA
# 50892    POLIO           11                       0.11  RUBELLA
# 50893    POLIO            1                       0.08  RUBELLA
# 50894    POLIO            1                       0.04  RUBELLA
# 50895    POLIO            1                       0.03  RUBELLA
# 50896    POLIO            1                       0.01  RUBELLA
# 50897    POLIO            1                       0.04  RUBELLA
# 50898    POLIO            1                       0.03  RUBELLA
# 50899    POLIO            1                       0.05  RUBELLA
# 50900    POLIO            5                       0.88  RUBELLA
# 50901    POLIO            1                       0.08  RUBELLA
# 50902    POLIO            2                       0.04  RUBELLA
# 50903    POLIO            2                       0.03  RUBELLA
# 50904    POLIO            2                       0.14  RUBELLA
# 50905    POLIO            2                       0.06  RUBELLA
# 50906    POLIO            6                       0.08  RUBELLA
# 50907    POLIO            5                       0.75  RUBELLA
# 50908    POLIO            1                       0.03  RUBELLA
# 50909    POLIO            4                       0.04  RUBELLA
# 50910    POLIO            7                       0.26  RUBELLA
# 50911    POLIO            3                       0.12  RUBELLA
# 50912    POLIO            1                       0.18  RUBELLA
# 50913    POLIO            1                       0.01  RUBELLA
# 50914    POLIO            3                       0.10  RUBELLA
# 50915    POLIO            1                       0.03  RUBELLA
#
#        rubella cases rubella incidence_per_capita   disease  smallpox cases  \
# 0                  7                         0.20  SMALLPOX               1
# 1                 29                         1.80  SMALLPOX               7
# 2                  7                         0.04  SMALLPOX               0
# 3                 11                         0.38  SMALLPOX              18
# 4                  1                         0.14  SMALLPOX              31
# 5                  6                         0.22  SMALLPOX              26
# 6                  1                         0.15  SMALLPOX               0
# 7                 17                         0.16  SMALLPOX               1
# 8                 21                         0.42  SMALLPOX               0
# 9                 14                         0.44  SMALLPOX              58
# 10                10                         0.18  SMALLPOX               4
# 11                 6                         0.16  SMALLPOX              30
# 12                 4                         0.40  SMALLPOX             133
# 13                25                         0.29  SMALLPOX              73
# 14                 2                         0.06  SMALLPOX              16
# 15                 1                         0.02  SMALLPOX              10
# 16                11                         1.56  SMALLPOX               0
# 17                 7                         1.08  SMALLPOX               0
# 18                 9                         1.32  SMALLPOX               0
# 19                22                         1.12  SMALLPOX              17
# 20                 1                         0.01  SMALLPOX               2
# 21                 6                         0.67  SMALLPOX              38
# 22                 4                         0.16  SMALLPOX               1
# 23                23                         0.60  SMALLPOX              36
# 24                 3                         0.07  SMALLPOX              63
# 25                 2                         0.48  SMALLPOX              12
# 26                70                         2.29  SMALLPOX               3
# 27                40                         0.94  SMALLPOX               1
# 28                23                         1.30  SMALLPOX               4
# 29                 1                         0.31  SMALLPOX              19
# ...              ...                          ...       ...             ...
# 50886              0                         0.00  SMALLPOX               2
# 50887              0                         0.00  SMALLPOX               1
# 50888              0                         0.00  SMALLPOX               1
# 50889             11                         0.05  SMALLPOX               1
# 50890              0                         0.00  SMALLPOX               1
# 50891              0                         0.00  SMALLPOX               1
# 50892              0                         0.00  SMALLPOX               1
# 50893              0                         0.00  SMALLPOX               1
# 50894              0                         0.00  SMALLPOX               1
# 50895              0                         0.00  SMALLPOX               1
# 50896              0                         0.00  SMALLPOX               1
# 50897              0                         0.00  SMALLPOX               1
# 50898              0                         0.00  SMALLPOX               1
# 50899              0                         0.00  SMALLPOX               1
# 50900              0                         0.00  SMALLPOX               1
# 50901              0                         0.00  SMALLPOX               2
# 50902              0                         0.00  SMALLPOX               2
# 50903              2                         0.01  SMALLPOX               1
# 50904              0                         0.00  SMALLPOX               1
# 50905              1                         0.00  SMALLPOX               1
# 50906              0                         0.00  SMALLPOX               1
# 50907              0                         0.00  SMALLPOX               2
# 50908              0                         0.00  SMALLPOX               1
# 50909              0                         0.00  SMALLPOX               1
# 50910              0                         0.00  SMALLPOX               1
# 50911              0                         0.00  SMALLPOX               1
# 50912              0                         0.00  SMALLPOX               1
# 50913              0                         0.00  SMALLPOX               1
# 50914              2                         0.03  SMALLPOX               1
# 50915              1                         0.02  SMALLPOX               1
#
#       smallpox incidence_per_capita
# 0                              0.04
# 1                              0.38
# 2                              0.00
# 3                              0.34
# 4                              3.06
# 5                              1.65
# 6                              0.00
# 7                              0.07
# 8                              0.00
# 9                              2.37
# 10                             0.89
# 11                             0.40
# 12                             4.14
# 13                             3.95
# 14                             0.62
# 15                             0.48
# 16                             0.00
# 17                             0.00
# 18                             0.00
# 19                             0.36
# 20                             0.08
# 21                             1.06
# 22                             0.05
# 23                             6.65
# 24                             2.04
# 25                             0.88
# 26                             0.08
# 27                             0.24
# 28                             0.03
# 29                             0.29
# ...                             ...
# 50886                          0.25
# 50887                          0.02
# 50888                          0.13
# 50889                          0.03
# 50890                          0.17
# 50891                          0.08
# 50892                          0.03
# 50893                          0.02
# 50894                          0.03
# 50895                          0.15
# 50896                          0.03
# 50897                          0.60
# 50898                          0.34
# 50899                          0.01
# 50900                          0.01
# 50901                          0.15
# 50902                          0.34
# 50903                          0.34
# 50904                          0.01
# 50905                          0.12
# 50906                          0.55
# 50907                          0.24
# 50908                          0.08
# 50909                          0.05
# 50910                          0.03
# 50911                          0.14
# 50912                          0.55
# 50913                          0.17
# 50914                          0.15
# 50915                          0.04
#
# [50916 rows x 22 columns]

# %%
resetcasesstatedf = df_9.reset_index()
resetcasesstatedf.head()
# Out:
#    index  state_name      disease  Hepatitis A cases  \
# 0      0     ALABAMA  HEPATITIS A                  5
# 1      1    ARKANSAS  HEPATITIS A                 11
# 2      2     ARIZONA  HEPATITIS A                  6
# 3      3  CALIFORNIA  HEPATITIS A                 89
# 4      4    COLORADO  HEPATITIS A                  1
#
#    Hepatitis A incidence_per_capita  disease  measles cases  \
# 0                              0.14  MEASLES             97
# 1                              0.58  MEASLES             76
# 2                              0.37  MEASLES              8
# 3                              0.47  MEASLES             74
# 4                              0.05  MEASLES             85
#
#    measles incidence_per_capita disease  mumps cases  ...  \
# 0                          3.67   MUMPS            7  ...
# 1                          4.11   MUMPS           39  ...
# 2                          1.90   MUMPS           19  ...
# 3                          1.38   MUMPS          247  ...
# 4                          8.38   MUMPS            1  ...
#
#    pertussis incidence_per_capita disease  polio cases  \
# 0                            0.79   POLIO            0
# 1                            1.14   POLIO            0
# 2                            4.08   POLIO            0
# 3                            5.86   POLIO            9
# 4                            0.90   POLIO            4
#
#    polio incidence_per_capita  disease rubella cases  \
# 0                        0.00  RUBELLA             7
# 1                        0.00  RUBELLA            29
# 2                        0.00  RUBELLA             7
# 3                        0.17  RUBELLA            11
# 4                        0.39  RUBELLA             1
#
#    rubella incidence_per_capita   disease  smallpox cases  \
# 0                          0.20  SMALLPOX               1
# 1                          1.80  SMALLPOX               7
# 2                          0.04  SMALLPOX               0
# 3                          0.38  SMALLPOX              18
# 4                          0.14  SMALLPOX              31
#
#    smallpox incidence_per_capita
# 0                           0.04
# 1                           0.38
# 2                           0.00
# 3                           0.34
# 4                           3.06
#
# [5 rows x 23 columns]

# %%
resetcasesstatedf.dtypes
# Out:
# index                                 int64
# state_name                           object
# disease                              object
# Hepatitis A cases                     int64
# Hepatitis A incidence_per_capita    float64
# disease                              object
# measles cases                         int64
# measles incidence_per_capita        float64
# disease                              object
# mumps cases                           int64
# mumps incidence_per_capita          float64
# disease                              object
# pertussis cases                       int64
# pertussis incidence_per_capita      float64
# disease                              object
# polio cases                          object
# polio incidence_per_capita          float64
# disease                              object
# rubella cases                         int64
# rubella incidence_per_capita        float64
# disease                              object
# smallpox cases                        int64
# smallpox incidence_per_capita       float64
# dtype: object

# %%
groupstatedf = resetcasesstatedf.groupby(["state_name"])
sum_groupstatedf = groupstatedf.sum()
sum_groupstatedf.head()
# Out:
#                index  Hepatitis A cases  Hepatitis A incidence_per_capita  \
# state_name
# ALABAMA     26370796               5424                            147.96
# ALASKA      18798770               4851                           1179.85
# ARIZONA     28992938              21611                            788.05
# ARKANSAS    25542384               5825                            269.42
# CALIFORNIA  28931364             149508                            660.33
#
#             measles cases  measles incidence_per_capita  mumps cases  \
# state_name
# ALABAMA            225456                       7770.56        17918
# ALASKA             143521                       5742.70        10699
# ARIZONA            234183                       8754.23        14537
# ARKANSAS           219097                       8820.17        17666
# CALIFORNIA         232275                       8791.60        18787
#
#             mumps incidence_per_capita  pertussis cases  \
# state_name
# ALABAMA                         498.47            47754
# ALASKA                          353.26            28190
# ARIZONA                         474.37            47197
# ARKANSAS                        498.96            42672
# CALIFORNIA                      522.40            48169
#
#             pertussis incidence_per_capita  polio incidence_per_capita  \
# state_name
# ALABAMA                            1779.28                      152.29
# ALASKA                             1082.26                      118.31
# ARIZONA                            1740.29                      183.24
# ARKANSAS                           1678.00                      149.30
# CALIFORNIA                         1784.80                      193.55
#
#             rubella cases  rubella incidence_per_capita  smallpox cases  \
# state_name
# ALABAMA             11021                        279.68            4681
# ALASKA               5202                        151.44            3240
# ARIZONA              8593                        231.89            5429
# ARKANSAS             9124                        206.36            4468
# CALIFORNIA           9055                        265.62            5125
#
#             smallpox incidence_per_capita
# state_name
# ALABAMA                            278.90
# ALASKA                             168.74
# ARIZONA                            256.65
# ARKANSAS                           219.16
# CALIFORNIA                         300.03

# %%
sum_groupstatedf.dtypes
# Out:
# index                                 int64
# Hepatitis A cases                     int64
# Hepatitis A incidence_per_capita    float64
# measles cases                         int64
# measles incidence_per_capita        float64
# mumps cases                           int64
# mumps incidence_per_capita          float64
# pertussis cases                       int64
# pertussis incidence_per_capita      float64
# polio incidence_per_capita          float64
# rubella cases                         int64
# rubella incidence_per_capita        float64
# smallpox cases                        int64
# smallpox incidence_per_capita       float64
# dtype: object

# %%
groupstatedf = df_9.groupby(["state_name"])
mean_groupstatedf = groupstatedf.mean()
mean_groupstatedf.head()
# Out:
#             Hepatitis A cases  Hepatitis A incidence_per_capita  \
# state_name
# ALABAMA              5.136364                          0.140114
# ALASKA               6.851695                          1.666455
# ARIZONA             19.434353                          0.708678
# ARKANSAS             5.784508                          0.267547
# CALIFORNIA         132.307965                          0.584363
#
#             measles cases  measles incidence_per_capita  mumps cases  \
# state_name
# ALABAMA        213.500000                      7.358485    16.967803
# ALASKA         202.713277                      8.111158    15.111582
# ARIZONA        210.596223                      7.872509    13.072842
# ARKANSAS       217.573982                      8.758858    17.543198
# CALIFORNIA     205.553097                      7.780177    16.625664
#
#             mumps incidence_per_capita  pertussis cases  \
# state_name
# ALABAMA                       0.472036        45.221591
# ALASKA                        0.498955        39.816384
# ARIZONA                       0.426592        42.443345
# ARKANSAS                      0.495492        42.375372
# CALIFORNIA                    0.462301        42.627434
#
#             pertussis incidence_per_capita  polio incidence_per_capita  \
# state_name
# ALABAMA                           1.684924                    0.144214
# ALASKA                            1.528616                    0.167105
# ARIZONA                           1.565009                    0.164784
# ARKANSAS                          1.666336                    0.148262
# CALIFORNIA                        1.579469                    0.171283
#
#             rubella cases  rubella incidence_per_capita  smallpox cases  \
# state_name
# ALABAMA         10.436553                      0.264848        4.432765
# ALASKA           7.347458                      0.213898        4.576271
# ARIZONA          7.727518                      0.208534        4.882194
# ARKANSAS         9.060576                      0.204926        4.436941
# CALIFORNIA       8.013274                      0.235062        4.535398
#
#             smallpox incidence_per_capita
# state_name
# ALABAMA                          0.264110
# ALASKA                           0.238333
# ARIZONA                          0.230800
# ARKANSAS                         0.217637
# CALIFORNIA                       0.265513

# %%
resetcasesstatedf = mean_groupstatedf.reset_index()
resetcasesstatedf.head()
# Out:
#    state_name  Hepatitis A cases  Hepatitis A incidence_per_capita  \
# 0     ALABAMA           5.136364                          0.140114
# 1      ALASKA           6.851695                          1.666455
# 2     ARIZONA          19.434353                          0.708678
# 3    ARKANSAS           5.784508                          0.267547
# 4  CALIFORNIA         132.307965                          0.584363
#
#    measles cases  measles incidence_per_capita  mumps cases  \
# 0     213.500000                      7.358485    16.967803
# 1     202.713277                      8.111158    15.111582
# 2     210.596223                      7.872509    13.072842
# 3     217.573982                      8.758858    17.543198
# 4     205.553097                      7.780177    16.625664
#
#    mumps incidence_per_capita  pertussis cases  \
# 0                    0.472036        45.221591
# 1                    0.498955        39.816384
# 2                    0.426592        42.443345
# 3                    0.495492        42.375372
# 4                    0.462301        42.627434
#
#    pertussis incidence_per_capita  polio incidence_per_capita  rubella cases  \
# 0                        1.684924                    0.144214      10.436553
# 1                        1.528616                    0.167105       7.347458
# 2                        1.565009                    0.164784       7.727518
# 3                        1.666336                    0.148262       9.060576
# 4                        1.579469                    0.171283       8.013274
#
#    rubella incidence_per_capita  smallpox cases  smallpox incidence_per_capita
# 0                      0.264848        4.432765                       0.264110
# 1                      0.213898        4.576271                       0.238333
# 2                      0.208534        4.882194                       0.230800
# 3                      0.204926        4.436941                       0.217637
# 4                      0.235062        4.535398                       0.265513

# %%
casesstatedf = resetcasesstatedf[["state_name", "Hepatitis A cases", "measles cases","mumps cases", "pertussis cases",  "rubella cases", "smallpox cases"]]
casesstatedf.head()
# Out:
#    state_name  Hepatitis A cases  measles cases  mumps cases  pertussis cases  \
# 0     ALABAMA           5.136364     213.500000    16.967803        45.221591
# 1      ALASKA           6.851695     202.713277    15.111582        39.816384
# 2     ARIZONA          19.434353     210.596223    13.072842        42.443345
# 3    ARKANSAS           5.784508     217.573982    17.543198        42.375372
# 4  CALIFORNIA         132.307965     205.553097    16.625664        42.627434
#
#    rubella cases  smallpox cases
# 0      10.436553        4.432765
# 1       7.347458        4.576271
# 2       7.727518        4.882194
# 3       9.060576        4.436941
# 4       8.013274        4.535398

# %%
incidencepercapitadf = resetcasesstatedf[["state_name", "Hepatitis A incidence_per_capita", "measles incidence_per_capita", "mumps incidence_per_capita", "pertussis incidence_per_capita", "polio incidence_per_capita", "rubella incidence_per_capita", "smallpox incidence_per_capita"]]
incidencepercapitadf.head()
# Out:
#    state_name  Hepatitis A incidence_per_capita  measles incidence_per_capita  \
# 0     ALABAMA                          0.140114                      7.358485
# 1      ALASKA                          1.666455                      8.111158
# 2     ARIZONA                          0.708678                      7.872509
# 3    ARKANSAS                          0.267547                      8.758858
# 4  CALIFORNIA                          0.584363                      7.780177
#
#    mumps incidence_per_capita  pertussis incidence_per_capita  \
# 0                    0.472036                        1.684924
# 1                    0.498955                        1.528616
# 2                    0.426592                        1.565009
# 3                    0.495492                        1.666336
# 4                    0.462301                        1.579469
#
#    polio incidence_per_capita  rubella incidence_per_capita  \
# 0                    0.144214                      0.264848
# 1                    0.167105                      0.213898
# 2                    0.164784                      0.208534
# 3                    0.148262                      0.204926
# 4                    0.171283                      0.235062
#
#    smallpox incidence_per_capita
# 0                       0.264110
# 1                       0.238333
# 2                       0.230800
# 3                       0.217637
# 4                       0.265513
